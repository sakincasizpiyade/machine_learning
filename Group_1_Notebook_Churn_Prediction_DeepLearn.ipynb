# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "***Employee Churn Analysis Project***". This is the second project of Capstone Project Series, which you will be able to build your own classification models for a variety of business settings.
#
# Also you will research what is Employee Churn?, How it is different from customer churn, Exploratory data analysis and visualization of employee churn dataset using ***matplotlib*** and ***seaborn***, model building and evaluation using python ***scikit-learn*** and ***Tensorflow-Keras*** packages.
#
# You will be able to implement classification techniques in Python. Using Scikit-Learn allowing you to successfully make predictions with Distance Based, Bagging, Boosting algorithms for this project. On the other hand, for Deep Learning you will use Tensorflow-Keras.
#
# After taking Machine learning deployment course, you will able to deploy your model using *Streamlit*.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - NOTE: This project assumes that you already know the basics of coding in Python and are familiar with model deployement as well as the theory behind Distance Based, Bagging, Boosting algorithms, and Confusion Matrices. You can try more models and methods beside these to improve your model metrics.

# %% [markdown]
# # #Determines
# In this project you have HR data of a company. A study is requested from you to predict which employee will churn by using this data.
#
# The HR dataset has 14,999 samples. In the given dataset, you have two types of employee one who stayed and another who left the company.
#
# You can describe 10 attributes in detail as:
# - ***satisfaction_level:*** It is employee satisfaction point, which ranges from 0-1.
# - ***last_evaluation:*** It is evaluated performance by the employer, which also ranges from 0-1.
# - ***number_projects:*** How many of projects assigned to an employee?
# - ***average_monthly_hours:*** How many hours in averega an employee worked in a month?
# - **time_spent_company:** time_spent_company means employee experience. The number of years spent by an employee in the company.
# - ***work_accident:*** Whether an employee has had a work accident or not.
# - ***promotion_last_5years:*** Whether an employee has had a promotion in the last 5 years or not.
# - ***Departments:*** Employee's working department/division.
# - ***Salary:*** Salary level of the employee such as low, medium and high.
# - ***left:*** Whether the employee has left the company or not.
#
# First of all, to observe the structure of the data, outliers, missing values and features that affect the target variable, you must use exploratory data analysis and data visualization techniques.
#
# Then, you must perform data pre-processing operations such as ***Scaling*** and ***Encoding*** to increase the accuracy score of Gradient Descent Based or Distance-Based algorithms.
#
# You are asked to perform ***Cluster Analysis*** based on the information you obtain during exploratory data analysis and data visualization processes. The purpose of clustering analysis is to cluster data with similar characteristics.
#
# Once the data is ready to be applied to the model, you must ***split the data into train and test***. Then build a model to predict whether employees will churn or not. Train your models with your train set, test the success of your model with your test set.
#
# Try to make your predictions by using the ***Classification Algorithms***. You can use the related modules of the ***scikit-learn*** and ***Tensorflow-Keras*** library. You can use scikit-learn ***Classification Metrics*** module for accuracy calculation.
#
# Data drift and model drirft are key consepts about ML and MLOPS, you can monitor and check your data and models with plenty of ways and tools. ***Deepchecks*** is one of them and the leading tool for testing and for validating your machine learning models and data, and it enables doing so with minimal effort. In this project, you will apply ***Data Integrity, Train-Test Validation, and Model Evaluation*** checks.
# Deepchecks Introduction : https://youtu.be/7ELdizoi6BU

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis
# - EDA is an initial process of analysis, in which you can summarize characteristics of data such as pattern, trends, outliers, and hypothesis testing using descriptive statistics and visualization.
# - In the given dataset, you have two types of employee one who stayed and another who left the company. So, you can divide data into two groups and compare their characteristics.
#
# #### 2. Data Visualization
# - Explore your data via visualizations to find-out:
#  - What can be the reason of the churn?
#  - Behavioral analysis of churns and not churns ..... etc.
#
# #### 3. Cluster Analysis
# - Apply ***clustering algorithms*** and writedown your conclusions about the clusters you created.
#
# #### 5. Predictive Model Building
# - Split Data as Train and Test set
# - Built Classification Models(at least four models) and Evaluate Model Performances
#
# #### 6. Model Deployement
#
# - Save and Export the Best Model

# %% [markdown]
# ## #Importing Modules and Predefined Functions#

# %%
# !pip install scikeras

# %%
# !pip install scikit-plot

# %%
# !pip install livelossplot

# %%
# !pip install optuna
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 10.8 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from sklearn.compose import ColumnTransformer
from sklearn.experimental import enable_halving_search_cv

from sklearn.metrics import classification_report, confusion_matrix, \
                                RocCurveDisplay, roc_auc_score, roc_curve, \
                                classification_report, confusion_matrix, \
                                accuracy_score, recall_score, f1_score, \
                                precision_score, precision_recall_curve, \
                                average_precision_score
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, \
                                    GridSearchCV, HalvingGridSearchCV, RandomizedSearchCV

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, StandardScaler

from sklearn.utils.class_weight import compute_class_weight

from scikitplot.metrics import plot_roc, precision_recall_curve,average_precision_score

# %%
from scikeras.wrappers import KerasClassifier

from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam

from keras.metrics import BinaryAccuracy, Precision, Recall, F1Score
from livelossplot import PlotLossesKerasTF

import optuna
import pickle

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
pd.set_option("display.float_format", lambda x: "%.3f" % x)
pd.set_option("display.max_columns", None)
plt.rcParams["figure.figsize"] = (8, 6)
sns.set_style("darkgrid")

# %%
# version control
import matplotlib
import sklearn
import tensorflow as tf

# !python --version # python version
print()
print("Pandas ", pd.__version__)
print("NumPy ", np.__version__)
print("Matplotlib ", matplotlib.__version__)
print("Seaborn ", sns.__version__)
print("Scikit-Learn ", sklearn.__version__)
print("Tensor-Flow ", tf.__version__)
# Out:
# Python 3.10.12
#
# Pandas  1.5.3
# NumPy  1.23.5
# Matplotlib  3.7.1
# Seaborn  0.12.2
# Scikit-Learn  1.2.2
# Tensor-Flow  2.14.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 4.0 reading dataset

# %%
# df0 = pd.read_csv('HR_Dataset_DL.csv')
df0 = pd.read_csv('drive/MyDrive/Colab Notebooks/data/HR_Dataset_DL.csv')

# %%
df = df0.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11991 entries, 0 to 11990
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   departments            11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 936.9+ KB

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.380            0.530               2                   157
# 1               0.800            0.860               5                   262
# 2               0.110            0.880               7                   272
# 3               0.720            0.870               5                   223
# 4               0.370            0.520               2                   159
#
#    time_spend_company  work_accident  left  promotion_last_5years departments  \
# 0                   3              0     1                      0       sales
# 1                   6              0     1                      0       sales
# 2                   4              0     1                      0       sales
# 3                   5              0     1                      0       sales
# 4                   3              0     1                      0       sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.shape
# Out:
# (11991, 10)

# %% [markdown]
# ## 4. Predictive Model Building

# %% [markdown]
# ### 4.1. Train-Test Validation Checks
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_train_test_validation.html

# %% [markdown]
# ### 4.2. Preprocessing

# %%
seed = 42
os.environ["TF_DETERMINISTIC_OPS"] = "1"
keras.utils.set_random_seed(seed)

# %%
df['left'].value_counts(normalize = True)
# Out:
# 0   0.834
# 1   0.166
# Name: left, dtype: float64

# %%
X = df.drop(columns = ['left'])
y = df['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed)
X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  stratify=y_train,
                                                  test_size=0.15,
                                                  random_state=seed)

# %%
X_train.shape
# Out:
# (9172, 9)

# %%
X_test.shape
# Out:
# (1200, 9)

# %%
X_val.shape
# Out:
# (1619, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11991 entries, 0 to 11990
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   departments            11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 936.9+ KB

# %%
X_train.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 7024               0.680            0.610               3
# 8697               0.640            0.790               4
# 9673               0.220            1.000               6
# 2394               0.480            0.690               4
# 6583               0.820            0.520               5
#
#       average_montly_hours  time_spend_company  work_accident  \
# 7024                   134                   4              0
# 8697                   274                   2              1
# 9673                   244                   3              0
# 2394                   222                   2              0
# 6583                   225                   2              0
#
#       promotion_last_5years departments  salary
# 7024                      0       sales  medium
# 8697                      0   technical     low
# 9673                      0          IT  medium
# ...

# %%
#ordinal encoding for salary column

ordinal = OrdinalEncoder(categories = [['low', 'medium', 'high']])

X_train['salary'] = ordinal.fit_transform(X_train[['salary']])
X_val['salary'] = ordinal.transform(X_val[['salary']])
X_test  ['salary'] = ordinal.transform(X_test[['salary']])

# %%
X_train.salary.value_counts()
# Out:
# 0.000    4396
# 1.000    4005
# 2.000     771
# Name: salary, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',
                        sparse=False,
                        drop='first',
                        handle_unknown="ignore")

transformers = [('dept', encoder, ['departments'])]

col_transformer = ColumnTransformer(transformers=transformers,
                                    remainder=MinMaxScaler())

# %%
transformed_data = pd.DataFrame(col_transformer.fit_transform(X_train))


transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_train.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_train = transformed_data
X_train.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   0.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   1.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    0.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              1.000                0.000                  0.000
# ...

# %%
transformed_data = pd.DataFrame(col_transformer.transform(X_val))


transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_val.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_val = transformed_data
X_val.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   0.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   0.000           1.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  1.000                    0.000
# 3                   0.000                  0.000                    0.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              0.000                1.000                  0.000
# ...

# %%
transformed_data = pd.DataFrame(col_transformer.transform(X_test))


transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_test.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_test = transformed_data
X_test.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   1.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   0.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    1.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              0.000                1.000                  0.000
# ...

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ### 4.3. Classification Algorithms
#  - Try at least 4 ML/DL algorithms.

# %%
X_train.shape
# Out:
# (9172, 17)

# %%
batch_size = 64
epochs = 200
patience = 30

# %% [markdown]
# #### 4.3.1. Model Building, Evaluating  and Tuning

# %% [markdown]
# #### 4.3.1.1. Vanilla modeling

# %%
vanilla = Sequential()

vanilla.add(Dense(26, activation='relu', input_dim=X_train.shape[1])) #17*1,5
vanilla.add(Dense(13, activation='relu'))
vanilla.add(Dense(5, activation='relu'))
vanilla.add(Dense(1, activation='sigmoid'))

vanilla.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
vanilla.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 26)                468
#
#  dense_5 (Dense)             (None, 13)                351
#
#  dense_6 (Dense)             (None, 5)                 70
#
#  dense_7 (Dense)             (None, 1)                 6
#
# ...
# Total params: 895 (3.50 KB)
# Trainable params: 895 (3.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = dict(enumerate(class_weights))

# %%
print('Balanced weight')
print(f'w0: {class_weights_dict[0]}')
print(f'w1: {class_weights_dict[1]}')
# Out:
# Balanced weight
# w0: 0.5995554974506472
# w1: 3.011162179908076

# %%
vanilla.fit(x=X_train,
            y=y_train,
            validation_data=(X_val,y_val),
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            callbacks=[PlotLossesKerasTF()],
            class_weight=class_weights_dict )
# Out:
# accuracy
# 	training         	 (min:    0.418, max:    0.977, cur:    0.976)
# 	validation       	 (min:    0.520, max:    0.966, cur:    0.965)
# Loss
# 	training         	 (min:    0.098, max:    0.659, cur:    0.098)
# 	validation       	 (min:    0.137, max:    0.736, cur:    0.159)
# precision
# 	training         	 (min:    0.213, max:    0.912, cur:    0.907)
# 	validation       	 (min:    0.248, max:    0.894, cur:    0.879)
# recall
# 	training         	 (min:    0.915, max:    0.957, cur:    0.955)
# 	validation       	 (min:    0.874, max:    0.941, cur:    0.914)
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0979 - accuracy: 0.9762 - precision: 0.9065 - recall: 0.9554 - val_loss: 0.1586 - val_accuracy: 0.9648 - val_precision: 0.8786 - val_recall: 0.9145

# %%
vanilla.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 26)                468
#
#  dense_5 (Dense)             (None, 13)                351
#
#  dense_6 (Dense)             (None, 5)                 70
#
#  dense_7 (Dense)             (None, 1)                 6
#
# ...
# Total params: 895 (3.50 KB)
# Trainable params: 895 (3.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# vanilla.save('DL_vanilla.h5')
vanilla.save('drive/MyDrive/Colab Notebooks/model/DL_vanilla.h5')

# %%
vanilla_loss_df = pd.DataFrame(vanilla.history.history)
vanilla_loss_df.tail()
# Out:
#      loss  accuracy  precision  recall  val_loss  val_accuracy  val_precision  \
# 195 0.102     0.974      0.901   0.951     0.157         0.960          0.862
# 196 0.100     0.975      0.905   0.952     0.158         0.960          0.862
# 197 0.101     0.975      0.902   0.953     0.164         0.961          0.860
# 198 0.100     0.976      0.905   0.955     0.167         0.963          0.867
# 199 0.098     0.976      0.907   0.955     0.159         0.965          0.879
#
#      val_recall
# 195       0.907
# 196       0.907
# 197       0.914
# 198       0.918
# 199       0.914

# %%
# vanilla_loss_df.plot()
vanilla_loss_df.plot(subplots=[['loss','val_loss'],
                            ['accuracy','val_accuracy'],
                            ['precision', 'val_precision'],
                            ['recall', 'val_recall']],
                            layout=(2,2),
                            figsize=(5,5));

# %%
def con_matrix(X_train, X_test, y_train, y_test, model, model_name='model'):

  y_pred = (model.predict(X_test) > 0.5).astype('int64')
  print(f'{model_name} - Test Confusion Matrix\n' + '*' * 50)
  print(confusion_matrix(y_test, y_pred))
  print(classification_report(y_test, y_pred))

  print()

  y_train_pred = (model.predict(X_train) > 0.5).astype('int64')
  print(f'{model_name} - Train Confusion Matrix\n' + '*' * 50)
  print(confusion_matrix(y_train, y_train_pred))
  print(classification_report(y_train, y_train_pred))

# %%
loss, accuracy, precision, recall = vanilla.evaluate(X_test, y_test, verbose=0)
print("vanilla loss: ", loss)
print("vanilla accuracy: ", accuracy)
print("vanilla precision ", precision)
print("vanilla recall: ", recall)
# Out:
# vanilla loss:  0.14594273269176483
# vanilla accuracy:  0.9583333134651184
# vanilla precision  0.843317985534668
# vanilla recall:  0.9195979833602905

# %%
con_matrix(X_train, X_test, y_train, y_test, vanilla, 'Vanilla')
# Out:
# 38/38 [==============================] - 1s 2ms/step
# Vanilla - Test Confusion Matrix
# **************************************************
# [[967  34]
#  [ 16 183]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      1001
#            1       0.84      0.92      0.88       199
#
#     accuracy                           0.96      1200
#    macro avg       0.91      0.94      0.93      1200
# weighted avg       0.96      0.96      0.96      1200
#
#
# 287/287 [==============================] - 1s 2ms/step
# Vanilla - Train Confusion Matrix
# **************************************************
# [[7529  120]
#  [  69 1454]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7649
#            1       0.92      0.95      0.94      1523
#
#     accuracy                           0.98      9172
#    macro avg       0.96      0.97      0.96      9172
# ...

# %%
y_pred_proba_vanilla = vanilla.predict(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred_proba_vanilla)
# Out:
# 38/38 [==============================] - 0s 3ms/step

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba_vanilla)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %% [markdown]
# ###### 4.3.1.1.1. Vanilla model cross validation

# %%
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units=26, activation="relu", input_dim=X_train.shape[1]))
    classifier.add(Dense(units=13, activation="relu"))
    classifier.add(Dense(units=5, activation="relu"))
    classifier.add(Dense(units=1, activation="sigmoid"))
    classifier.compile(
        optimizer="adam", loss="binary_crossentropy", metrics=['accuracy', 'Precision', 'Recall', 'F1Score']
    )
    return classifier

# %%
classifier_model = KerasClassifier(
                                    model=build_classifier,
                                    batch_size=batch_size,
                                    epochs=100, verbose=0)

scores = cross_validate(
    estimator=classifier_model,
    X=X_train,
    y=y_train,
    scoring=["accuracy", "precision", "recall", "f1"],
    cv=10,
)

df_scores = pd.DataFrame(scores, index=range(1, 11)).iloc[:, 2:]

df_scores
# Out:
#     test_accuracy  test_precision  test_recall  test_f1
# 1           0.969           0.937        0.876    0.905
# 2           0.968           0.908        0.902    0.905
# 3           0.966           0.917        0.875    0.896
# 4           0.973           0.964        0.868    0.913
# 5           0.971           0.931        0.888    0.909
# 6           0.963           0.910        0.862    0.885
# 7           0.968           0.897        0.914    0.906
# 8           0.967           0.886        0.921    0.903
# 9           0.966           0.917        0.875    0.896
# 10          0.967           0.913        0.889    0.901

# %%
df_scores_summary = pd.DataFrame(
    {"score_mean": df_scores.mean().values, "score_std": df_scores.std().values},
    index=["accuracy", "precision", "recall", "f1"],
)

df_scores_summary
# Out:
#            score_mean  score_std
# accuracy        0.968      0.003
# precision       0.918      0.022
# recall          0.887      0.020
# f1              0.902      0.008

# %% [markdown]
# #### 4.3.1.2. Vanilla Learning Rate 0.003

# %%
vanilla_LR_0_003 = Sequential()

vanilla_LR_0_003.add(Dense(26, activation='relu', input_dim=X_train.shape[1])) #17*1,5
vanilla_LR_0_003.add(Dense(13, activation='relu'))
vanilla_LR_0_003.add(Dense(5, activation='relu'))
vanilla_LR_0_003.add(Dense(1, activation='sigmoid'))

opt = Adam(learning_rate=0.003)
vanilla_LR_0_003.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
vanilla_LR_0_003.fit(x=X_train,
            y=y_train,
            validation_data=(X_val,y_val),
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            callbacks=[PlotLossesKerasTF()],
            class_weight=class_weights_dict )
# Out:
# accuracy
# 	training         	 (min:    0.655, max:    0.979, cur:    0.979)
# 	validation       	 (min:    0.799, max:    0.967, cur:    0.948)
# Loss
# 	training         	 (min:    0.071, max:    0.577, cur:    0.071)
# 	validation       	 (min:    0.137, max:    0.503, cur:    0.224)
# precision
# 	training         	 (min:    0.292, max:    0.908, cur:    0.908)
# 	validation       	 (min:    0.446, max:    0.886, cur:    0.794)
# recall
# 	training         	 (min:    0.755, max:    0.972, cur:    0.968)
# 	validation       	 (min:    0.836, max:    0.937, cur:    0.929)
# 144/144 [==============================] - 3s 23ms/step - loss: 0.0715 - accuracy: 0.9785 - precision: 0.9083 - recall: 0.9685 - val_loss: 0.2239 - val_accuracy: 0.9481 - val_precision: 0.7937 - val_recall: 0.9294

# %%
# vanilla_LR_0_003.save('DL_vanilla_LR_0_003.h5')
vanilla_LR_0_003.save('drive/MyDrive/Colab Notebooks/model/DL_vanilla_LR_0_003.h5')

# %%
vanilla_LR_0_003_loss_df = pd.DataFrame(vanilla_LR_0_003.history.history)
vanilla_LR_0_003_loss_df.tail()

# %%
#vanilla_LR_0_003_loss_df.plot()
vanilla_LR_0_003_loss_df.plot(subplots=[['loss','val_loss'],
                            ['accuracy','val_accuracy'],
                            ['precision', 'val_precision'],
                            ['recall', 'val_recall']],
                            layout=(2,2),
                            figsize=(5,5));

# %%
loss, accuracy, precision, recall = vanilla_LR_0_003.evaluate(X_test, y_test, verbose=0)
print("vanilla LR 0.003 loss: ", loss)
print("vanilla LR 0.003 accuracy: ", accuracy)
print("vanilla LR 0.003 precision ", precision)
print("vanilla LR 0.003 recall: ", recall)
# Out:
# vanilla LR 0.003 loss:  0.1945728361606598
# vanilla LR 0.003 accuracy:  0.9549999833106995
# vanilla LR 0.003 precision  0.8165938854217529
# vanilla LR 0.003 recall:  0.9396985173225403

# %%
con_matrix(X_train, X_test, y_train, y_test, vanilla_LR_0_003, 'vanilla LR 0.003')
# Out:
# 38/38 [==============================] - 0s 2ms/step
# vanilla LR 0.003 - Test Confusion Matrix
# **************************************************
# [[959  42]
#  [ 12 187]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      1001
#            1       0.82      0.94      0.87       199
#
#     accuracy                           0.95      1200
#    macro avg       0.90      0.95      0.92      1200
# weighted avg       0.96      0.95      0.96      1200
#
#
# 287/287 [==============================] - 1s 2ms/step
# vanilla LR 0.003 - Train Confusion Matrix
# **************************************************
# [[7441  208]
#  [  31 1492]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      7649
#            1       0.88      0.98      0.93      1523
#
#     accuracy                           0.97      9172
#    macro avg       0.94      0.98      0.96      9172
# ...

# %%
y_pred_proba_vanilla_LR_0_003 = vanilla_LR_0_003.predict(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred_proba_vanilla_LR_0_003)
# Out:
# 38/38 [==============================] - 0s 2ms/step

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba_vanilla_LR_0_003)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %% [markdown]
# #### 4.3.1.3. Vanilla Early Stop LR 0.003

# %%
vanilla_LR_0_003_ES = Sequential()

vanilla_LR_0_003_Es.add(Dense(26, activation='relu', input_dim=X_train.shape[1])) #17*1,5
vanilla_LR_0_003_ES.add(Dense(13, activation='relu'))
vanilla_LR_0_003_ES.add(Dense(5, activation='relu'))
vanilla_LR_0_003_ES.add(Dense(1, activation='sigmoid'))

opt = Adam(learning_rate=0.003)
vanilla_LR_0_003_ES.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
early_stop = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=patience, restore_best_weights=True)

# %%
vanilla_LR_0_003_ES.fit(x=X_train,
            y=y_train,
            validation_data=(X_val,y_val),
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            callbacks=[early_stop, PlotLossesKerasTF()],
            class_weight=class_weights_dict )
# Out:
# accuracy
# 	training         	 (min:    0.763, max:    0.962, cur:    0.960)
# 	validation       	 (min:    0.746, max:    0.961, cur:    0.950)
# Loss
# 	training         	 (min:    0.116, max:    0.603, cur:    0.118)
# 	validation       	 (min:    0.139, max:    0.536, cur:    0.166)
# precision
# 	training         	 (min:    0.356, max:    0.839, cur:    0.829)
# 	validation       	 (min:    0.387, max:    0.858, cur:    0.807)
# recall
# 	training         	 (min:    0.532, max:    0.958, cur:    0.957)
# 	validation       	 (min:    0.911, max:    0.944, cur:    0.918)
# 144/144 [==============================] - 2s 16ms/step - loss: 0.1175 - accuracy: 0.9602 - precision: 0.8294 - recall: 0.9573 - val_loss: 0.1661 - val_accuracy: 0.9500 - val_precision: 0.8072 - val_recall: 0.9182
# Epoch 68: early stopping

# %%
# vanilla_LR_0_003_ES.save('DL_vanilla_LR_0_003_ES.h5')

vanilla_LR_0_003_ES.save('drive/MyDrive/Colab Notebooks/model/DL_vanilla_LR_0_003_ES.h5')

# %%
vanilla_LR_0_003_ES_loss_df = pd.DataFrame(vanilla_LR_0_003_ES.history.history)
vanilla_LR_0_003_ES_loss_df.tail()

# %%
# vanilla_LR_0_003_ES_loss_df.plot()
vanilla_LR_0_003_ES_loss_df.plot(subplots=[['loss','val_loss'],
                            ['accuracy','val_accuracy'],
                            ['precision', 'val_precision'],
                            ['recall', 'val_recall']],
                            layout=(2,2),
                            figsize=(5,5));

# %%
loss, accuracy, precision, recall = vanilla_LR_0_003_ES.evaluate(X_test, y_test, verbose=0)
print("vanilla loss: ", loss)
print("vanilla accuracy: ", accuracy)
print("vanilla precision ", precision)
print("vanilla recall: ", recall)

# %%
con_matrix(X_train, X_test, y_train, y_test, vanilla_LR_0_003_ES, 'Vanilla LR 0.003 Early Stop')

# %%
y_pred_proba_vanilla_LR_0_003_ES = vanilla.predict(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred_proba_vanilla_LR_0_003_ES)

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba_vanilla_LR_0_003_ES)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %% [markdown]
# ### Optuna

# %%
trial_metric = ['accuracy', 'Precision', 'Recall', 'F1Score']

def create_model(trial):

    n_units1 = trial.suggest_int("n_units1", 8, 128)
    n_units2 = trial.suggest_int("n_units2", 8, 128)
    n_units3 = trial.suggest_int("n_units3", 8, 128)
    n_units4 = trial.suggest_int("n_units4", 8, 128)

    optimizer = trial.suggest_categorical("optimizer", [Adam, Adadelta, RMSprop, Nadam])

    learning_rate = trial.suggest_loguniform("learning_rate", 1e-6, 1e-1)

    model = Sequential()
    model.add(Dense(n_units1, input_dim=X_train.shape[1], activation="relu"))
    model.add(Dense(n_units2, activation="relu"))
    model.add(Dense(n_units3, activation="relu"))
    model.add(Dense(n_units4, activation="relu"))

    model.add(Dense(1, activation="sigmoid"))

    model.compile(
        loss="binary_crossentropy",
        optimizer=optimizer(learning_rate=learning_rate),
        metrics=[trial_metric]
    )
    return model


def objective(trial):
    model = create_model(trial)
    w0 = trial.suggest_loguniform("w0", 0.001, 5)
    w1 = trial.suggest_loguniform("w1", 0.001, 5)
    model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        epochs=epochs,
        callbacks=[early_stop],
        class_weight={0: w0, 1: w1},
        verbose=0,
    )

    score = model.evaluate(X_test, y_test, verbose=0)[1]
    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=10)
study.best_params
# Out:
# [I 2023-11-17 17:44:42,320] A new study created in memory with name: no-name-1e58c2b4-9b8b-41d4-8f11-b037463bb639
# Restoring model weights from the end of the best epoch: 68.
# Epoch 98: early stopping
# [I 2023-11-17 17:47:06,074] Trial 0 finished with value: 0.9524999856948853 and parameters: {'n_units1': 63, 'n_units2': 23, 'n_units3': 17, 'n_units4': 21, 'optimizer': <class 'keras.src.optimizers.nadam.Nadam'>, 'learning_rate': 0.025999531439914226, 'w0': 0.9738718761706543, 'w1': 0.012181064289841772}. Best is trial 0 with value: 0.9524999856948853.
# Restoring model weights from the end of the best epoch: 1.
# Epoch 31: early stopping
# ...

# %%
unit1, unit2, unit3, unit4, optimizer, lr, w0, w1 = (
    study.best_params["n_units1"],
    study.best_params["n_units2"],
    study.best_params["n_units3"],
    study.best_params["n_units4"],
    study.best_params["optimizer"],
    study.best_params["learning_rate"],
    study.best_params["w0"],
    study.best_params["w1"],
)

optuna = Sequential()
optuna.add(Dense(unit1, activation="relu"))
optuna.add(Dense(unit2, activation="relu"))
optuna.add(Dense(unit3, activation="relu"))
optuna.add(Dense(unit4, activation="relu"))
optuna.add(Dense(1, activation="sigmoid"))
opt = optimizer(learning_rate=lr)
optuna.compile(optimizer=opt, loss="binary_crossentropy", metrics=['accuracy', 'Precision', 'Recall'])

# train model
optuna.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[early_stop],
    class_weight={0: w0, 1: w1},
    verbose=1,
)
# Out:
# Epoch 1/200
# 144/144 [==============================] - 3s 8ms/step - loss: 0.0028 - accuracy: 0.8301 - precision: 0.2034 - recall: 0.0079 - val_loss: 0.3677 - val_accuracy: 0.8338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/200
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0016 - accuracy: 0.8717 - precision: 0.9369 - recall: 0.2436 - val_loss: 0.2005 - val_accuracy: 0.9376 - val_precision: 0.9286 - val_recall: 0.6766
# Epoch 3/200
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0014 - accuracy: 0.9211 - precision: 0.9484 - recall: 0.5548 - val_loss: 0.4115 - val_accuracy: 0.8672 - val_precision: 0.9655 - val_recall: 0.2082
# Epoch 4/200
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0013 - accuracy: 0.9224 - precision: 0.9613 - recall: 0.5548 - val_loss: 0.2586 - val_accuracy: 0.9271 - val_precision: 0.9689 - val_recall: 0.5799
# Epoch 5/200
# ...

# %%
optuna.summary()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_136 (Dense)           (None, 126)               2268
#
#  dense_137 (Dense)           (None, 91)                11557
#
#  dense_138 (Dense)           (None, 123)               11316
#
#  dense_139 (Dense)           (None, 39)                4836
#
#  dense_140 (Dense)           (None, 1)                 40
#
# ...
# Total params: 30017 (117.25 KB)
# Trainable params: 30017 (117.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# optuna.save('DL_optuna.h5')

optuna.save('drive/MyDrive/Colab Notebooks/model/DL_optuna.h5')

# %%
optuna_loss_df = pd.DataFrame(optuna.history.history)
optuna_loss_df.tail()
# Out:
#     loss  accuracy  precision  recall  val_loss  val_accuracy  val_precision  \
# 78 0.001     0.965      0.989   0.798     0.198         0.943          0.978
# 79 0.001     0.964      0.987   0.794     0.139         0.968          0.966
# 80 0.001     0.970      0.991   0.827     0.147         0.962          0.964
# 81 0.001     0.970      0.990   0.827     0.154         0.968          0.970
# 82 0.001     0.971      0.985   0.837     0.185         0.962          0.977
#
#     val_recall
# 78       0.669
# 79       0.840
# 80       0.803
# 81       0.836
# 82       0.792

# %%
# optuna_loss_df.plot()
optuna_loss_df.plot(subplots=[['loss','val_loss'],
                            ['accuracy','val_accuracy'],
                            ['precision', 'val_precision'],
                            ['recall', 'val_recall']],
                            layout=(2,2),
                            figsize=(5,5));

# %%
loss, accuracy, precision, recall = optuna.evaluate(X_test, y_test, verbose=0)
print("optuna loss: ", loss)
print("optuna accuracy: ", accuracy)
print("optuna precision ", precision)
print("optuna recall: ", recall)
# Out:
# optuna loss:  0.10668380558490753
# optuna accuracy:  0.9708333611488342
# optuna precision  0.9767441749572754
# optuna recall:  0.8442211151123047

# %%
con_matrix(X_train, X_test, y_train, y_test, optuna, 'Optuna')
# Out:
# 38/38 [==============================] - 0s 2ms/step
# Optuna - Test Confusion Matrix
# **************************************************
# [[997   4]
#  [ 31 168]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      1001
#          1.0       0.98      0.84      0.91       199
#
#     accuracy                           0.97      1200
#    macro avg       0.97      0.92      0.94      1200
# weighted avg       0.97      0.97      0.97      1200
#
#
# 287/287 [==============================] - 1s 2ms/step
# Optuna - Train Confusion Matrix
# **************************************************
# [[7637   12]
#  [ 262 1261]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      7649
#          1.0       0.99      0.83      0.90      1523
#
#     accuracy                           0.97      9172
#    macro avg       0.98      0.91      0.94      9172
# ...

# %%
y_pred_proba_optuna = optuna.predict(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred_proba_optuna)
# Out:
# 38/38 [==============================] - 0s 3ms/step

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba_optuna)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %% [markdown]
# ##### 4.3.1.1 Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %% [markdown]
# #### 4.3.2. Compare Models Performances
# - Compare model performances according to metrics you choose for the problem.

# %%
vanilla = load_model('drive/MyDrive/Colab Notebooks/model/DL_vanilla.h5')
vanilla_LR_0_003 = load_model('drive/MyDrive/Colab Notebooks/model/DL_vanilla_LR_0_003.h5')
vanilla_LR_0_003_ES = load_model('drive/MyDrive/Colab Notebooks/model/DL_vanilla_LR_0_003_ES.h5')
optuna = load_model('drive/MyDrive/Colab Notebooks/model/DL_optuna.h5')

models = [vanilla, vanilla_LR_0_003, vanilla_LR_0_003_ES, optuna]
model_names = ['Vanilla', 'Vanilla LR 0.003', 'Vanilla LR 0.003 ES','Optuna' ]


compare = pd.DataFrame(columns=['Model', 'AUC', 'Accuracy', 'Precision','Recall'])


for model, model_name in zip(models, model_names):
    y_pred = model.predict(X_test)
    auc_score = roc_auc_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int))
    recall = recall_score(y_test, (y_pred > 0.5).astype(int))
    f1 = f1_score(y_test, (y_pred > 0.5).astype(int))

    compare = compare.append({'Model': model_name, 'AUC': auc_score, 'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1 Score': f1}, ignore_index=True)

compare
# Out:
# ...
# 38/38 [==============================] - 0s 2ms/step
#                  Model   AUC  Accuracy  Precision  Recall  F1 Score
# 0              Vanilla 0.972     0.958      0.843   0.920     0.880
# 1     Vanilla LR 0.003 0.976     0.955      0.817   0.940     0.874
# 2  Vanilla LR 0.003 ES 0.971     0.961      0.865   0.905     0.885
# 3               Optuna 0.981     0.971      0.977   0.844     0.906

# %%
plt.figure(figsize=(10,10))

plt.subplot(511)
compare = compare.sort_values(by="AUC", ascending=False)
ax=sns.barplot(x="AUC", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(512)
compare = compare.sort_values(by="Accuracy", ascending=False)
ax=sns.barplot(x="Accuracy", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(513)
compare = compare.sort_values(by="Precision", ascending=False)
ax=sns.barplot(x="Precision", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(514)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(515)
compare = compare.sort_values(by="F1 Score", ascending=False)
ax=sns.barplot(x="F1 Score", y="Model", data=compare, palette="Blues_d" )
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.tight_layout()
plt.show();

# %%
X_ = df.drop(columns= ["left"])
y_ = df.left

X_train_, X_test_, y_train_, y_test_ = train_test_split(X_, y_, test_size=0.2, random_state=seed, stratify = y_)

# %%
with open('drive/MyDrive/Colab Notebooks/model/logisticregression.pkl', 'rb') as file:
    logisticregression  = pickle.load(file)

with open('drive/MyDrive/Colab Notebooks/model/randomforest.pkl', 'rb') as file:
    randomforest  = pickle.load(file)

with open('drive/MyDrive/Colab Notebooks/model/gradientboost.pkl', 'rb') as file:
    gradientboost  = pickle.load(file)

with open('drive/MyDrive/Colab Notebooks/model/xgboost.pkl', 'rb') as file:
    xgboost  = pickle.load(file)

# %%
models = [logisticregression, randomforest, gradientboost, xgboost]
model_names = ["Logistic Regression", "Random Forest", "Gradient Boost" ,"XGBoost"]

# compare = pd.DataFrame(columns=['Model', 'AUC', 'Accuracy', 'Precision','Recall'])


for model, model_name in zip(models, model_names):
    y_pred = model.predict(X_test_)
    auc_score = roc_auc_score(y_test_, y_pred)
    accuracy = accuracy_score(y_test_, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test_, (y_pred > 0.5).astype(int))
    recall = recall_score(y_test_, (y_pred > 0.5).astype(int))
    f1 = f1_score(y_test_, (y_pred > 0.5).astype(int))

    compare = compare.append({'Model': model_name, 'AUC': auc_score, 'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1 Score': f1}, ignore_index=True)

compare
# Out:
#                  Model   AUC  Accuracy  Precision  Recall  F1 Score
# 0               Optuna 0.981     0.971      0.977   0.844     0.906
# 1  Vanilla LR 0.003 ES 0.971     0.961      0.865   0.905     0.885
# 2              Vanilla 0.972     0.958      0.843   0.920     0.880
# 3     Vanilla LR 0.003 0.976     0.955      0.817   0.940     0.874
# 4  Logistic Regression 0.806     0.782      0.422   0.842     0.562
# 5        Random Forest 0.961     0.985      0.981   0.925     0.952
# 6       Gradient Boost 0.962     0.986      0.987   0.927     0.956
# 7              XGBoost 0.960     0.980      0.951   0.930     0.940

# %%
plt.figure(figsize=(10,10))

plt.subplot(511)
compare = compare.sort_values(by="AUC", ascending=False)
ax=sns.barplot(x="AUC", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(512)
compare = compare.sort_values(by="Accuracy", ascending=False)
ax=sns.barplot(x="Accuracy", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(513)
compare = compare.sort_values(by="Precision", ascending=False)
ax=sns.barplot(x="Precision", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(514)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(515)
compare = compare.sort_values(by="F1 Score", ascending=False)
ax=sns.barplot(x="F1 Score", y="Model", data=compare, palette="Blues_d" )
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.tight_layout()
plt.show();

# %% [markdown]
# ####  4.3.3 Prediction
# - Make a demo prediction

# %%
pickle.dump(ordinal, open("ordinal_employee_churn", "wb"))
pickle.dump(col_transformer, open("scaler_employee_churn", "wb"))

ordinal = pickle.load(open("ordinal_employee_churn", "rb"))
col_transformer = pickle.load(open("scaler_employee_churn", "rb"))

# %%
df_predict = df.sample(n=5, random_state=seed)
df_predict.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                0.090            0.790               6
# 3098               0.740            0.960               4
# 9322               0.810            0.970               4
# 357                0.370            0.540               2
# 1323               0.100            0.770               6
#
#       average_montly_hours  time_spend_company  work_accident  left  \
# 396                    293                   5              0     1
# 3098                   154                   4              0     0
# 9322                   212                   2              0     0
# 357                    149                   3              0     1
# 1323                   272                   4              0     1
#
#       promotion_last_5years departments  salary
# 396                       0       sales     low
# 3098                      0     support  medium
# 9322                      0       sales     low
# ...

# %%
X_new = df_predict.drop(['left'], axis=1)
y_new = df_predict['left']

# %%
X_new.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                0.090            0.790               6
# 3098               0.740            0.960               4
# 9322               0.810            0.970               4
# 357                0.370            0.540               2
# 1323               0.100            0.770               6
#
#       average_montly_hours  time_spend_company  work_accident  \
# 396                    293                   5              0
# 3098                   154                   4              0
# 9322                   212                   2              0
# 357                    149                   3              0
# 1323                   272                   4              0
#
#       promotion_last_5years departments  salary
# 396                       0       sales     low
# 3098                      0     support  medium
# 9322                      0       sales     low
# ...

# %%
y_new.head()
# Out:
# 396     1
# 3098    0
# 9322    0
# 357     1
# 1323    1
# Name: left, dtype: int64

# %%
#ordinal encoding for salary column
X_new['salary'] = ordinal.transform(X_new[['salary']])

X_new.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                0.090            0.790               6
# 3098               0.740            0.960               4
# 9322               0.810            0.970               4
# 357                0.370            0.540               2
# 1323               0.100            0.770               6
#
#       average_montly_hours  time_spend_company  work_accident  \
# 396                    293                   5              0
# 3098                   154                   4              0
# 9322                   212                   2              0
# 357                    149                   3              0
# 1323                   272                   4              0
#
#       promotion_last_5years departments  salary
# 396                       0       sales   0.000
# 3098                      0     support   1.000
# 9322                      0       sales   0.000
# ...

# %%
transformed_data = pd.DataFrame(col_transformer.transform(X_new))
transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_new.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_new = transformed_data
X_new.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   0.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   1.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    0.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              1.000                0.000                  0.000
# ...

# %% [markdown]
# ## 5. Model Deployement
# - Finalize your model with whole dataset and prepare for the deployment.

# %% [markdown]
# ### 5.1. Final Model

# %%
# Final Model selection :vanilla LR 0.003 with Early Stop

prediction = pd.DataFrame(vanilla_LR_0_003.predict(X_new) > 0.5, columns=['predict']).astype("int32")

pd.concat([df_predict.reset_index(drop=True), prediction.reset_index(drop=True)], axis=1)
# Out:
# 1/1 [==============================] - 0s 27ms/step
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.090            0.790               6                   293
# 1               0.740            0.960               4                   154
# 2               0.810            0.970               4                   212
# 3               0.370            0.540               2                   149
# 4               0.100            0.770               6                   272
#
#    time_spend_company  work_accident  left  promotion_last_5years departments  \
# 0                   5              0     1                      0       sales
# 1                   4              0     0                      0     support
# 2                   2              0     0                      0       sales
# 3                   3              0     1                      0     support
# ...

# %% [markdown]
# ### 5.2. Save and Export the Best Model

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
